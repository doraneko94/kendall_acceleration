# %%
import kendall_py, time
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt

# %%
x = [6, 4, 9, 7, 3, 6, 1]
y = [2, 1, 4, 3, 2, 1, 2]

# %%
print("tau: {:.2f}".format(kendall_py.tau(x, y)))
zb = kendall_py.zb(x, y)
print("zB: {:.2f}".format(zb))
# Out:
# tau: 0.43
# zB: 1.28

# %%
np.random.seed(0)
plt.figure(figsize=(4, 3))
b = plt.hist(np.random.normal(size=100000), bins=50, alpha=0.6)
plt.hist(np.zeros(int(b[0][sum(b[1] < zb) - 1])) + zb, bins=b[1], color="r", label="$z_B$={:.2f}".format(zb))
plt.xlim(-4, 4)
plt.xlabel("$z_B$")
plt.legend()
plt.tick_params(left=False, labelleft=False)
plt.show()

# %%
print("上位 {:.2f}%".format((1 - sp.stats.norm.cdf(zb)) * 100))
# Out:
# 上位 9.97%

# %%
n = 100000
np.random.seed(1)
z = np.random.random(n)
x = z + np.random.random(n) * 0.5
y = z + np.random.random(n) * 0.5

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 2), sharex=True)
axes[0].plot(x[:500], c="C0")
axes[0].set_xlim(0, 500)
axes[0].set_ylabel("X")
axes[1].plot(y[:500], c="C1")
axes[1].set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
start = time.time()
tau = kendall_py.tau(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 22,164.24 ms
# tau: 0.60074

# %%
start = time.time()
tau = kendall_py.tau_avltree(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 88.97 ms
# tau: 0.60074

# %%
np.random.seed(2)
z = np.random.random(n)
x = z + np.random.random(n) * 0.5
y = z + np.random.random(n) * 0.5
x[z > np.random.random(n) * 0.2] = 0.0
y[z > np.random.random(n) * 0.2] = 0.0

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 2), sharex=True)
axes[0].plot(x[:500], c="C0")
axes[0].set_xlim(0, 500)
axes[0].set_ylabel("X")
axes[1].plot(y[:500], c="C1")
axes[1].set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
start = time.time()
tau = kendall_py.tau(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 11,109.96 ms
# tau: 0.58315

# %%
start = time.time()
tau = kendall_py.tau_avltree(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 62.52 ms
# tau: 0.92090

# %%
start = time.time()
tau = kendall_py.tau_zero(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 28.33 ms
# tau: 0.58315

# %%
np.random.seed(3)
z = np.random.random(n)
x = np.ones(n)
y = np.ones(n)
x[z > np.random.random(n) * 1] = 0.0
y[z > np.random.random(n) * 1] = 0.0

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 2), sharex=True)
axes[0].plot(x[:500], c="C0")
axes[0].set_xlim(0, 500)
axes[0].set_ylabel("X")
axes[1].plot(y[:500], c="C1")
axes[1].set_ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
start = time.time()
tau = kendall_py.tau(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 28,473.78 ms
# tau: 0.33312

# %%
x = x == 1
y = y == 1
start = time.time()
tau = kendall_py.tau_binary(x, y)
print("計算時間: {:,.2f} ms".format((time.time() - start) * 1000))
print("tau: {:.5f}".format(tau))
# Out:
# 計算時間: 44.00 ms
# tau: 0.33312
